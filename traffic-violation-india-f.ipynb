# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
pd.set_option("display.max_columns",None)
import os

# %%
#Lets load the data series
import pandas as pd

file_path = "/kaggle/input/indian-traffic-violation/Indian_Traffic_Violations.csv"  # Ensure the file exists

raw_data=pd.read_csv(file_path)
raw_data.head()
# Out:
#   Violation_ID           Violation_Type  Fine_Amount       Location  \
# 0    VLT100000              Overloading         4544      Karnataka
# 1    VLT100001  Driving Without License         2776         Punjab
# 2    VLT100002       Using Mobile Phone         4785    Maharashtra
# 3    VLT100003              No Seatbelt         1138  Uttar Pradesh
# 4    VLT100004            Over-speeding         1610      Karnataka
#
#          Date   Time Vehicle_Type Vehicle_Color  Vehicle_Model_Year  \
# 0  2023-01-01  23:02          Car           Red                2012
# 1  2023-01-02  00:42      Scooter        Silver                2010
# 2  2023-01-03  04:32      Scooter          Grey                2006
# 3  2023-01-04  15:06          Car         Green                1996
# 4  2023-01-05  06:57        Truck        Yellow                2016
#
#   Registration_State  Driver_Age Driver_Gender  License_Type  Penalty_Points  \
# 0        West Bengal          25          Male    Commercial               5
# 1         Tamil Nadu          32        Female    Commercial               4
# 2         Tamil Nadu          67        Female   Two-Wheeler               8
# 3      Uttar Pradesh          46          Male       Learner               3
# 4              Delhi          63        Female  Four-Wheeler               4
#
#   Weather_Condition Road_Condition Officer_ID  Issuing_Agency  \
# 0            Cloudy       Slippery    OFF9971    Local Police
# 1             Rainy            Dry    OFF6000  Highway Patrol
# 2             Clear       Potholes    OFF5706    Local Police
# 3             Rainy            Wet    OFF5575  Highway Patrol
# 4             Foggy       Potholes    OFF7147  Traffic Police
#
#   License_Validity  Number_of_Passengers Helmet_Worn Seatbelt_Worn  \
# 0            Valid                     4         NaN           Yes
# 1            Valid                     4         NaN            No
# 2            Valid                     5         Yes           Yes
# 3            Valid                     2          No            No
# 4            Valid                     4         NaN            No
#
#   Traffic_Light_Status  Speed_Limit  Recorded_Speed  Alcohol_Level  \
# 0                Green          100              95           0.03
# 1                Green           40              48           0.45
# 2               Yellow           80              26           0.31
# 3                Green          100             115           0.09
# 4                  Red           30             115           0.28
#
#   Breathalyzer_Result Towed Fine_Paid Payment_Method  \
# 0            Negative   Yes        No         Online
# 1            Negative   Yes       Yes         Online
# 2       Not Conducted    No        No       Not Paid
# 3       Not Conducted    No       Yes         Online
# 4            Positive    No       Yes           Cash
#
#   Court_Appearance_Required  Previous_Violations         Comments
# 0                       Yes                    3  Repeat Offender
# 1                        No                    2  Repeat Offender
# 2                       Yes                    4              NaN
# 3                        No                    5  Repeat Offender
# 4                       Yes                    0              NaN

# %%
raw_data.shape
raw_data.columns
# Out:
# Index(['Violation_ID', 'Violation_Type', 'Fine_Amount', 'Location', 'Date',
#        'Time', 'Vehicle_Type', 'Vehicle_Color', 'Vehicle_Model_Year',
#        'Registration_State', 'Driver_Age', 'Driver_Gender', 'License_Type',
#        'Penalty_Points', 'Weather_Condition', 'Road_Condition', 'Officer_ID',
#        'Issuing_Agency', 'License_Validity', 'Number_of_Passengers',
#        'Helmet_Worn', 'Seatbelt_Worn', 'Traffic_Light_Status', 'Speed_Limit',
#        'Recorded_Speed', 'Alcohol_Level', 'Breathalyzer_Result', 'Towed',
#        'Fine_Paid', 'Payment_Method', 'Court_Appearance_Required',
#        'Previous_Violations', 'Comments'],
#       dtype='object')

# %%
cleaned_data_frame=raw_data[['Violation_Type', 'Fine_Amount', 'Location', 'Date', 'Vehicle_Type',
       'Registration_State', 'Driver_Age', 'Driver_Gender', 'License_Type','Weather_Condition', 'Road_Condition', 'Officer_ID',
       'Issuing_Agency', 'License_Validity', 
       'Helmet_Worn', 'Seatbelt_Worn', 'Traffic_Light_Status', 'Speed_Limit',
       'Recorded_Speed', 'Alcohol_Level', 'Court_Appearance_Required',
       'Previous_Violations', 'Comments']]

cleaned_data_frame.head()
# Out:
#             Violation_Type  Fine_Amount       Location        Date  \
# 0              Overloading         4544      Karnataka  2023-01-01
# 1  Driving Without License         2776         Punjab  2023-01-02
# 2       Using Mobile Phone         4785    Maharashtra  2023-01-03
# 3              No Seatbelt         1138  Uttar Pradesh  2023-01-04
# 4            Over-speeding         1610      Karnataka  2023-01-05
#
#   Vehicle_Type Registration_State  Driver_Age Driver_Gender  License_Type  \
# 0          Car        West Bengal          25          Male    Commercial
# 1      Scooter         Tamil Nadu          32        Female    Commercial
# 2      Scooter         Tamil Nadu          67        Female   Two-Wheeler
# 3          Car      Uttar Pradesh          46          Male       Learner
# 4        Truck              Delhi          63        Female  Four-Wheeler
#
#   Weather_Condition Road_Condition Officer_ID  Issuing_Agency  \
# 0            Cloudy       Slippery    OFF9971    Local Police
# 1             Rainy            Dry    OFF6000  Highway Patrol
# 2             Clear       Potholes    OFF5706    Local Police
# 3             Rainy            Wet    OFF5575  Highway Patrol
# 4             Foggy       Potholes    OFF7147  Traffic Police
#
#   License_Validity Helmet_Worn Seatbelt_Worn Traffic_Light_Status  \
# 0            Valid         NaN           Yes                Green
# 1            Valid         NaN            No                Green
# 2            Valid         Yes           Yes               Yellow
# 3            Valid          No            No                Green
# 4            Valid         NaN            No                  Red
#
#    Speed_Limit  Recorded_Speed  Alcohol_Level Court_Appearance_Required  \
# 0          100              95           0.03                       Yes
# 1           40              48           0.45                        No
# 2           80              26           0.31                       Yes
# 3          100             115           0.09                        No
# 4           30             115           0.28                       Yes
#
#    Previous_Violations         Comments
# 0                    3  Repeat Offender
# 1                    2  Repeat Offender
# 2                    4              NaN
# 3                    5  Repeat Offender
# 4                    0              NaN

# %%
cleaned_data_frame.shape
# Out:
# (4000, 23)

# %%
cleaned_data_frame.dtypes
# Out:
# Violation_Type                object
# Fine_Amount                    int64
# Location                      object
# Date                          object
# Vehicle_Type                  object
# Registration_State            object
# Driver_Age                     int64
# Driver_Gender                 object
# License_Type                  object
# Weather_Condition             object
# Road_Condition                object
# Officer_ID                    object
# Issuing_Agency                object
# License_Validity              object
# Helmet_Worn                   object
# Seatbelt_Worn                 object
# Traffic_Light_Status          object
# Speed_Limit                    int64
# Recorded_Speed                 int64
# Alcohol_Level                float64
# Court_Appearance_Required     object
# Previous_Violations            int64
# Comments                      object
# dtype: object

# %%
cleaned_data_frame["Year"]=cleaned_data_frame["Date"].str.split("-").str[0].copy()
cleaned_data_frame.head()
cleaned_data_frame.drop(columns="Date").copy()
cleaned_data_frame.head()
# Out:
# <ipython-input-99-dbe8b0f8b2fb>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Violation_Type  Fine_Amount       Location        Date  \
# 0              Overloading         4544      Karnataka  2023-01-01
# 1  Driving Without License         2776         Punjab  2023-01-02
# 2       Using Mobile Phone         4785    Maharashtra  2023-01-03
# 3              No Seatbelt         1138  Uttar Pradesh  2023-01-04
# 4            Over-speeding         1610      Karnataka  2023-01-05
#
#   Vehicle_Type Registration_State  Driver_Age Driver_Gender  License_Type  \
# 0          Car        West Bengal          25          Male    Commercial
# 1      Scooter         Tamil Nadu          32        Female    Commercial
# 2      Scooter         Tamil Nadu          67        Female   Two-Wheeler
# 3          Car      Uttar Pradesh          46          Male       Learner
# 4        Truck              Delhi          63        Female  Four-Wheeler
#
#   Weather_Condition Road_Condition Officer_ID  Issuing_Agency  \
# 0            Cloudy       Slippery    OFF9971    Local Police
# 1             Rainy            Dry    OFF6000  Highway Patrol
# 2             Clear       Potholes    OFF5706    Local Police
# 3             Rainy            Wet    OFF5575  Highway Patrol
# 4             Foggy       Potholes    OFF7147  Traffic Police
#
#   License_Validity Helmet_Worn Seatbelt_Worn Traffic_Light_Status  \
# 0            Valid         NaN           Yes                Green
# 1            Valid         NaN            No                Green
# 2            Valid         Yes           Yes               Yellow
# 3            Valid          No            No                Green
# 4            Valid         NaN            No                  Red
#
#    Speed_Limit  Recorded_Speed  Alcohol_Level Court_Appearance_Required  \
# 0          100              95           0.03                       Yes
# 1           40              48           0.45                        No
# 2           80              26           0.31                       Yes
# 3          100             115           0.09                        No
# 4           30             115           0.28                       Yes
#
#    Previous_Violations         Comments  Year
# 0                    3  Repeat Offender  2023
# 1                    2  Repeat Offender  2023
# 2                    4              NaN  2023
# 3                    5  Repeat Offender  2023
# 4                    0              NaN  2023

# %%
cleaned_data_frame.drop(["Officer_ID","Comments","Helmet_Worn","Seatbelt_Worn","Date"],axis=1)
ax1=cleaned_data_frame["Vehicle_Type"].value_counts().plot(kind="bar",color="skyblue")
ax1.set_ylabel("Counts of vechile")
ax1.set_xlabel("Vehicle Name")
ax1.set_title("Number of Vehicles")
# Out:
# Text(0.5, 1.0, 'Number of Vehicles')

# %%
cleaned_data_frame["Violation_Type"].astype("category").cat.codes
cleaned_data_frame.head(5)
# Out:
#             Violation_Type  Fine_Amount       Location        Date  \
# 0              Overloading         4544      Karnataka  2023-01-01
# 1  Driving Without License         2776         Punjab  2023-01-02
# 2       Using Mobile Phone         4785    Maharashtra  2023-01-03
# 3              No Seatbelt         1138  Uttar Pradesh  2023-01-04
# 4            Over-speeding         1610      Karnataka  2023-01-05
#
#   Vehicle_Type Registration_State  Driver_Age Driver_Gender  License_Type  \
# 0          Car        West Bengal          25          Male    Commercial
# 1      Scooter         Tamil Nadu          32        Female    Commercial
# 2      Scooter         Tamil Nadu          67        Female   Two-Wheeler
# 3          Car      Uttar Pradesh          46          Male       Learner
# 4        Truck              Delhi          63        Female  Four-Wheeler
#
#   Weather_Condition Road_Condition Officer_ID  Issuing_Agency  \
# 0            Cloudy       Slippery    OFF9971    Local Police
# 1             Rainy            Dry    OFF6000  Highway Patrol
# 2             Clear       Potholes    OFF5706    Local Police
# 3             Rainy            Wet    OFF5575  Highway Patrol
# 4             Foggy       Potholes    OFF7147  Traffic Police
#
#   License_Validity Helmet_Worn Seatbelt_Worn Traffic_Light_Status  \
# 0            Valid         NaN           Yes                Green
# 1            Valid         NaN            No                Green
# 2            Valid         Yes           Yes               Yellow
# 3            Valid          No            No                Green
# 4            Valid         NaN            No                  Red
#
#    Speed_Limit  Recorded_Speed  Alcohol_Level Court_Appearance_Required  \
# 0          100              95           0.03                       Yes
# 1           40              48           0.45                        No
# 2           80              26           0.31                       Yes
# 3          100             115           0.09                        No
# 4           30             115           0.28                       Yes
#
#    Previous_Violations         Comments  Year
# 0                    3  Repeat Offender  2023
# 1                    2  Repeat Offender  2023
# 2                    4              NaN  2023
# 3                    5  Repeat Offender  2023
# 4                    0              NaN  2023

# %%
ax1=cleaned_data_frame["Location"].value_counts().plot(kind="bar",title="Violation areawise")
ax1.set_ylabel("Counts areawise")
ax1.set_facecolor("white")
ax1.set_xlabel("Location[Staewise]")
# Out:
# Text(0.5, 0, 'Location[Staewise]')

# %%
cleaned_data_frame.head(2)
# Out:
#             Violation_Type  Fine_Amount   Location        Date Vehicle_Type  \
# 0              Overloading         4544  Karnataka  2023-01-01          Car
# 1  Driving Without License         2776     Punjab  2023-01-02      Scooter
#
#   Registration_State  Driver_Age Driver_Gender License_Type Weather_Condition  \
# 0        West Bengal          25          Male   Commercial            Cloudy
# 1         Tamil Nadu          32        Female   Commercial             Rainy
#
#   Road_Condition Officer_ID  Issuing_Agency License_Validity Helmet_Worn  \
# 0       Slippery    OFF9971    Local Police            Valid         NaN
# 1            Dry    OFF6000  Highway Patrol            Valid         NaN
#
#   Seatbelt_Worn Traffic_Light_Status  Speed_Limit  Recorded_Speed  \
# 0           Yes                Green          100              95
# 1            No                Green           40              48
#
#    Alcohol_Level Court_Appearance_Required  Previous_Violations  \
# 0           0.03                       Yes                    3
# 1           0.45                        No                    2
#
#           Comments  Year
# 0  Repeat Offender  2023
# 1  Repeat Offender  2023

# %%
cleaned_data_frame.Driver_Age.corr(cleaned_data_frame.Fine_Amount)
# Out:
# 0.006102380428190278

# %%
numerical_dataframe = cleaned_data_frame.select_dtypes(include=['number'])  # Fixed

sns.heatmap(numerical_dataframe.corr(),cmap="Reds",annot=True)
# Out:
# <Axes: >

# %%
cleaned_data_frame.describe()
# Out:
#        Fine_Amount   Driver_Age  Speed_Limit  Recorded_Speed  Alcohol_Level  \
# count  4000.000000  4000.000000  4000.000000     4000.000000    4000.000000
# mean   2529.821250    46.658000    59.817500       69.479000       0.251408
# std    1417.415712    16.865858    23.633267       29.394652       0.143744
# min     100.000000    18.000000    30.000000       20.000000       0.000000
# 25%    1280.750000    32.000000    40.000000       43.000000       0.130000
# 50%    2506.000000    47.000000    60.000000       70.000000       0.250000
# 75%    3733.000000    61.000000    80.000000       95.000000       0.380000
# max    5000.000000    75.000000   100.000000      120.000000       0.500000
#
#        Previous_Violations
# count           4000.00000
# mean               2.47750
# std                1.71398
# min                0.00000
# 25%                1.00000
# 50%                2.00000
# 75%                4.00000
# max                5.00000

# %%
numerical_dataframe
# Out:
#       Fine_Amount  Driver_Age  Speed_Limit  Recorded_Speed  Alcohol_Level  \
# 0            4544          25          100              95           0.03
# 1            2776          32           40              48           0.45
# 2            4785          67           80              26           0.31
# 3            1138          46          100             115           0.09
# 4            1610          63           30             115           0.28
# ...           ...         ...          ...             ...            ...
# 3995         2180          21          100              90           0.15
# 3996         2708          69          100              90           0.21
# 3997         3163          63           60              54           0.28
# 3998         1691          43           30              77           0.28
# 3999         2133          24           50             105           0.34
#
#       Previous_Violations
# 0                       3
# 1                       2
# 2                       4
# 3                       5
# 4                       0
# ...                   ...
# 3995                    2
# 3996                    4
# 3997                    2
# 3998                    2
# 3999                    4
#
# [4000 rows x 6 columns]

# %%
cleaned_data_frame.head(2)
# Out:
#             Violation_Type  Fine_Amount   Location        Date Vehicle_Type  \
# 0              Overloading         4544  Karnataka  2023-01-01          Car
# 1  Driving Without License         2776     Punjab  2023-01-02      Scooter
#
#   Registration_State  Driver_Age Driver_Gender License_Type Weather_Condition  \
# 0        West Bengal          25          Male   Commercial            Cloudy
# 1         Tamil Nadu          32        Female   Commercial             Rainy
#
#   Road_Condition Officer_ID  Issuing_Agency License_Validity Helmet_Worn  \
# 0       Slippery    OFF9971    Local Police            Valid         NaN
# 1            Dry    OFF6000  Highway Patrol            Valid         NaN
#
#   Seatbelt_Worn Traffic_Light_Status  Speed_Limit  Recorded_Speed  \
# 0           Yes                Green          100              95
# 1            No                Green           40              48
#
#    Alcohol_Level Court_Appearance_Required  Previous_Violations  \
# 0           0.03                       Yes                    3
# 1           0.45                        No                    2
#
#           Comments  Year
# 0  Repeat Offender  2023
# 1  Repeat Offender  2023

# %%
numerical_dataframe.Driver_Age.corr(numerical_dataframe.Fine_Amount)
# Out:
# 0.006102380428190278

# %%
cleaned_data_frame.head(2)
# Out:
#             Violation_Type  Fine_Amount   Location        Date Vehicle_Type  \
# 0              Overloading         4544  Karnataka  2023-01-01          Car
# 1  Driving Without License         2776     Punjab  2023-01-02      Scooter
#
#   Registration_State  Driver_Age Driver_Gender License_Type Weather_Condition  \
# 0        West Bengal          25          Male   Commercial            Cloudy
# 1         Tamil Nadu          32        Female   Commercial             Rainy
#
#   Road_Condition Officer_ID  Issuing_Agency License_Validity Helmet_Worn  \
# 0       Slippery    OFF9971    Local Police            Valid         NaN
# 1            Dry    OFF6000  Highway Patrol            Valid         NaN
#
#   Seatbelt_Worn Traffic_Light_Status  Speed_Limit  Recorded_Speed  \
# 0           Yes                Green          100              95
# 1            No                Green           40              48
#
#    Alcohol_Level Court_Appearance_Required  Previous_Violations  \
# 0           0.03                       Yes                    3
# 1           0.45                        No                    2
#
#           Comments  Year
# 0  Repeat Offender  2023
# 1  Repeat Offender  2023

# %%
df=cleaned_data_frame.copy()


violation=df["Violation_Type"].value_counts()
violation_df=pd.DataFrame(violation)
violation_df.head()
# Out:
#                          count
# Violation_Type
# Drunk Driving              488
# No Helmet                  463
# Wrong Parking              454
# Driving Without License    451
# Over-speeding              448

# %%
ax=sns.lineplot(violation_df,x="Violation_Type",y="count",marker="o",color="black",markersize=10)
ax.set_facecolor("skyblue")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_xlabel("Rule violation Types")
ax1.set_xlabel("Number of Violants")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# <ipython-input-112-2ea5a715230c>:3: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
# Text(0.5, 23.999999999999986, 'Number of Violants')

# %%
df.head(2)
# Out:
#             Violation_Type  Fine_Amount   Location        Date Vehicle_Type  \
# 0              Overloading         4544  Karnataka  2023-01-01          Car
# 1  Driving Without License         2776     Punjab  2023-01-02      Scooter
#
#   Registration_State  Driver_Age Driver_Gender License_Type Weather_Condition  \
# 0        West Bengal          25          Male   Commercial            Cloudy
# 1         Tamil Nadu          32        Female   Commercial             Rainy
#
#   Road_Condition Officer_ID  Issuing_Agency License_Validity Helmet_Worn  \
# 0       Slippery    OFF9971    Local Police            Valid         NaN
# 1            Dry    OFF6000  Highway Patrol            Valid         NaN
#
#   Seatbelt_Worn Traffic_Light_Status  Speed_Limit  Recorded_Speed  \
# 0           Yes                Green          100              95
# 1            No                Green           40              48
#
#    Alcohol_Level Court_Appearance_Required  Previous_Violations  \
# 0           0.03                       Yes                    3
# 1           0.45                        No                    2
#
#           Comments  Year
# 0  Repeat Offender  2023
# 1  Repeat Offender  2023

# %%
grouped_data=df.groupby("Vehicle_Type")[["Recorded_Speed","Alcohol_Level","Driver_Age"]].mean().reset_index()
fig,ax=plt.subplots(1,2,figsize=(14,5))

sns.barplot(data=grouped_data, x="Vehicle_Type", y="Recorded_Speed",hue="Alcohol_Level",ax=ax[0])
ax[0].set_title("Speed vs Vehicle type")
ax[0].set_xlabel("Vehicle Name")
ax[0].set_ylabel("Speed[Mph]")
ax[0].set_facecolor("white")
sns.lineplot(data=grouped_data,x="Driver_Age",y="Alcohol_Level",hue="Recorded_Speed",marker="*",markersize=10,ax=ax[1])
fig.patch.set_facecolor('lightblue')
ax[1].set_facecolor('lightyellow')
ax[1].set_title("Driver Age vs Alcohol Level Representation")
ax[1].set_xlabel("Age of Drivers")
ax[1].set_ylabel("Alcohol Level")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1075: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1075: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1075: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1075: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1075: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1075: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# Text(0, 0.5, 'Alcohol Level')

# %%
grouped_data_next=df.groupby(["Vehicle_Type","Driver_Age"])[["Recorded_Speed","Alcohol_Level"]].mean()
grouped_data_next
# Out:
#                           Recorded_Speed  Alcohol_Level
# Vehicle_Type  Driver_Age
# Auto Rickshaw 18               70.600000       0.265000
#               19               82.444444       0.190000
#               20               58.625000       0.201250
#               21               79.200000       0.234000
#               22               56.714286       0.297143
# ...                                  ...            ...
# Truck         71               83.181818       0.171818
#               72               48.363636       0.244545
#               73               54.428571       0.164286
#               74               56.411765       0.308824
#               75               76.500000       0.306429
#
# [348 rows x 2 columns]

# %%
court=df["Court_Appearance_Required"].value_counts()
fig,ax=plt.subplots(1,2,figsize=(14,5))
ax[0].pie(court,labels=(["Yes","No"]),autopct='%1.1f%%')
ax[0].set_title("Gulties sent to jail or not")
ax[1].bar(["Yes","No"],height=court)
# Out:
# <BarContainer object of 2 artists>

# %%
df.head(2)
# Out:
#             Violation_Type  Fine_Amount   Location        Date Vehicle_Type  \
# 0              Overloading         4544  Karnataka  2023-01-01          Car
# 1  Driving Without License         2776     Punjab  2023-01-02      Scooter
#
#   Registration_State  Driver_Age Driver_Gender License_Type Weather_Condition  \
# 0        West Bengal          25          Male   Commercial            Cloudy
# 1         Tamil Nadu          32        Female   Commercial             Rainy
#
#   Road_Condition Officer_ID  Issuing_Agency License_Validity Helmet_Worn  \
# 0       Slippery    OFF9971    Local Police            Valid         NaN
# 1            Dry    OFF6000  Highway Patrol            Valid         NaN
#
#   Seatbelt_Worn Traffic_Light_Status  Speed_Limit  Recorded_Speed  \
# 0           Yes                Green          100              95
# 1            No                Green           40              48
#
#    Alcohol_Level Court_Appearance_Required  Previous_Violations  \
# 0           0.03                       Yes                    3
# 1           0.45                        No                    2
#
#           Comments  Year
# 0  Repeat Offender  2023
# 1  Repeat Offender  2023

# %%
license=pd.DataFrame(df.License_Validity.value_counts()).reset_index()
license.columns = ['License_Validity', 'count']
import plotly.express as px
license
# Out:
#   License_Validity  count
# 0        Suspended   1371
# 1            Valid   1322
# 2          Expired   1307

# %%
fig = px.bar(license, y='License_Validity', x='count', title="License Validity vs Count")
fig.update_layout(
    width=800, 
    height=300,
    xaxis_title="Count",
    yaxis_title="license"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b1ca98d7-1c61-4411-a737-24a7081dcb9e" class="plotly-graph-div" style="height:300px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1ca98d7-1c61-4411-a737-24a7081dcb9e")) {                    Plotly.newPlot(                        "b1ca98d7-1c61-4411-a737-24a7081dcb9e",                        [{"alignmentgroup":"True","hovertemplate":"count=%{x}\u003cbr\u003eLicense_Validity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[1371,1322,1307],"xaxis":"x","y":["Suspended","Valid","Expired"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"t ...

# %%
df.Alcohol_Level.max()
df.Alcohol_Level.min()
df["Alcoholic"]=df["Alcohol_Level"]>0
df.Alcoholic.value_counts()
# Out:
# Alcoholic
# True     3960
# False      40
# Name: count, dtype: int64

# %%
df_1=df.Alcoholic.value_counts().reset_index()
df_1.columns=["Alcoholic","count"]

import plotly_express as px 
set_fig=px.bar(df_1,x="count",y="Alcoholic")
set_fig.update_layout(xaxis_title="Number of violents who are alcoholic",yaxis_title="True False based on alcoholic or not",title="Representation of violents who are alcoholic and non alcoholic")
set_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ac1c12a2-5dc4-45ea-835a-ed3a6a34a081" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac1c12a2-5dc4-45ea-835a-ed3a6a34a081")) {                    Plotly.newPlot(                        "ac1c12a2-5dc4-45ea-835a-ed3a6a34a081",                        [{"alignmentgroup":"True","hovertemplate":"count=%{x}\u003cbr\u003eAlcoholic=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[3960,40],"xaxis":"x","y":[true,false],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"typ ...

# %%
df["Overspeed"]=df["Recorded_Speed"]>df["Speed_Limit"]
df.head()
df.Overspeed.value_counts()


df["Overspeed_and_Alcoholic"]=df["Overspeed"] & df["Alcoholic"]
df.Overspeed_and_Alcoholic.value_counts()

df.columns
# Out:
# Index(['Violation_Type', 'Fine_Amount', 'Location', 'Date', 'Vehicle_Type',
#        'Registration_State', 'Driver_Age', 'Driver_Gender', 'License_Type',
#        'Weather_Condition', 'Road_Condition', 'Officer_ID', 'Issuing_Agency',
#        'License_Validity', 'Helmet_Worn', 'Seatbelt_Worn',
#        'Traffic_Light_Status', 'Speed_Limit', 'Recorded_Speed',
#        'Alcohol_Level', 'Court_Appearance_Required', 'Previous_Violations',
#        'Comments', 'Year', 'Alcoholic', 'Overspeed',
#        'Overspeed_and_Alcoholic'],
#       dtype='object')

# %%
df_clean=df.drop(["Vehicle_Type","Registration_State","Driver_Gender","License_Type","Weather_Condition","Road_Condition","Officer_ID", 'Issuing_Agency',
       'License_Validity', 'Helmet_Worn', 'Seatbelt_Worn',
       'Traffic_Light_Status','Court_Appearance_Required', 'Previous_Violations',
       'Year',"Location"],axis=1)

# %%
def get_alcoholic(x):
    if x==True:
        return "Yes"
    elif x==False:
        return "No"
    else:
        return "No"

df_clean["Alcoholic"]=df_clean["Alcoholic"].apply(lambda x:get_alcoholic(x))




def get_overspeed(x):
    if x==True:
        return "Yes"
    elif x==False:
        return "No"
    else:
        return "No"

df_clean["Overspeed"]=df_clean["Overspeed"].apply(lambda x:get_overspeed(x))

def get_overspeednd(x):
    if x==True:
        return "Yes"
    elif x==False:
        return "No"
    else:
        return "No"

df_clean["Overspeed_and_Alcoholic"]=df_clean["Overspeed_and_Alcoholic"].apply(lambda x:get_overspeednd(x))

# %%
from sklearn.model_selection import train_test_split

train_df,test_df=train_test_split(df_clean,test_size=0.2)
train_df.shape
# Out:
# (3200, 11)

# %%
numerical_col=df_clean.select_dtypes(include=["number"]).reset_index()
catagorical_col=df_clean.select_dtypes('object').reset_index()
sns.heatmap(numerical_col.corr(),cmap="Reds",annot=True)
# Out:
# <Axes: >

# %%
#Lets select the target columns and input columns
input_col = list(train_df.columns)
input_col = [col for i, col in enumerate(input_col) if i != 4]
print(input_col)

target_col="Recorded_Speed"
df_clean.head(2)
# Out:
# ['Violation_Type', 'Fine_Amount', 'Date', 'Driver_Age', 'Recorded_Speed', 'Alcohol_Level', 'Comments', 'Alcoholic', 'Overspeed', 'Overspeed_and_Alcoholic']
#             Violation_Type  Fine_Amount        Date  Driver_Age  Speed_Limit  \
# 0              Overloading         4544  2023-01-01          25          100
# 1  Driving Without License         2776  2023-01-02          32           40
#
#    Recorded_Speed  Alcohol_Level         Comments Alcoholic Overspeed  \
# 0              95           0.03  Repeat Offender       Yes        No
# 1              48           0.45  Repeat Offender       Yes       Yes
#
#   Overspeed_and_Alcoholic
# 0                      No
# 1                     Yes

# %%
train_inputs=train_df[input_col].copy()
train_target=train_df[target_col].copy()

# %%
type(train_target)
# Out:
# pandas.core.series.Series

# %%
#Convert_colomns to numeric dataframe 
numeric_col1=train_df.select_dtypes(include=["number"])
catagorical_column1=train_inputs.select_dtypes('object')

# %%
numeric_col1.describe()
numeric_col_final=list(numeric_col1)
numeric_col_final
# Out:
# ['Fine_Amount', 'Driver_Age', 'Speed_Limit', 'Recorded_Speed', 'Alcohol_Level']

# %%
catagorical_col=list(catagorical_column1)
train_df[catagorical_col].describe()
# Out:
#        Violation_Type        Date         Comments Alcoholic Overspeed  \
# count            3200        3200             2410      3200      3200
# unique              9        3200                3         2         2
# top     Drunk Driving  2028-08-21  First Violation       Yes       Yes
# freq              393           1              822      3164      1885
#
#        Overspeed_and_Alcoholic
# count                     3200
# unique                       2
# top                        Yes
# freq                      1862

# %%
train_df[catagorical_col].Violation_Type.unique()
# Out:
# array(['No Helmet', 'Wrong Parking', 'Signal Jumping',
#        'Using Mobile Phone', 'Over-speeding', 'Drunk Driving',
#        'Driving Without License', 'Overloading', 'No Seatbelt'],
#       dtype=object)

# %%
train_df.reset_index()
train_inputs.reset_index()
train_target.reset_index()
# Out:
#       index  Recorded_Speed
# 0      2059              94
# 1       564              73
# 2      2847              60
# 3      1701              74
# 4      3380              37
# ...     ...             ...
# 3195   1528              43
# 3196   3243              85
# 3197   2140             111
# 3198    723              49
# 3199    732              64
#
# [3200 rows x 2 columns]

# %%
#Lets train the dataseries
#Replacing nun values with mean we will use imputer for this 

from sklearn.impute import SimpleImputer

imputer=SimpleImputer(strategy="mean")

numerical_col=list(numeric_col_final)
df_clean[numeric_col_final].isna().sum()
# Out:
# Fine_Amount       0
# Driver_Age        0
# Speed_Limit       0
# Recorded_Speed    0
# Alcohol_Level     0
# dtype: int64

# %%
imputer.fit(df_clean[numeric_col_final])
list(imputer.statistics_)
# Out:
# [2529.82125, 46.658, 59.8175, 69.479, 0.2514075]

# %%
train_df[numeric_col_final]=imputer.transform(train_df[numeric_col_final])
train_df[numeric_col_final].describe()
# Out:
#        Fine_Amount   Driver_Age  Speed_Limit  Recorded_Speed  Alcohol_Level
# count  3200.000000  3200.000000  3200.000000     3200.000000    3200.000000
# mean   2526.850625    46.680000    59.884375       69.350938       0.251409
# std    1421.660376    16.919355    23.798789       29.396870       0.143493
# min     100.000000    18.000000    30.000000       20.000000       0.000000
# 25%    1252.500000    32.000000    40.000000       43.000000       0.130000
# 50%    2528.000000    47.000000    60.000000       69.000000       0.250000
# 75%    3715.250000    61.250000    80.000000       95.000000       0.380000
# max    4999.000000    75.000000   100.000000      120.000000       0.500000

# %% [markdown]
# # Scaling neumeric feature

# %%
numeric_col_final=train_inputs.select_dtypes(include=["number"])
numeric_col_final=list(numeric_col_final)
numeric_col_final
# Out:
# ['Fine_Amount', 'Driver_Age', 'Recorded_Speed', 'Alcohol_Level']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaler.fit(train_df[numeric_col_final])
# Out:
# MinMaxScaler()

# %%
scaler.data_max_
scaler.data_min_
# Out:
# array([100.,  18.,  20.,   0.])

# %%
train_inputs[numeric_col_final]=scaler.transform(train_inputs[numeric_col_final])
train_inputs
# Out:
#           Violation_Type  Fine_Amount        Date  Driver_Age  Recorded_Speed  \
# 2059           No Helmet     0.344356  2028-08-21    0.228070            0.74
# 564        Wrong Parking     0.620739  2024-07-18    0.192982            0.53
# 2847      Signal Jumping     0.734640  2030-10-18    0.578947            0.40
# 1701  Using Mobile Phone     0.765054  2027-08-29    0.561404            0.54
# 3380       Over-speeding     0.345172  2032-04-03    0.105263            0.17
# ...                  ...          ...         ...         ...             ...
# 1528         No Seatbelt     0.565013  2027-03-09    0.105263            0.23
# 3243       Over-speeding     0.208818  2031-11-18    0.614035            0.65
# 2140      Signal Jumping     0.073689  2028-11-10    0.052632            0.91
# 723        Drunk Driving     0.265564  2024-12-24    0.421053            0.29
# 732        Drunk Driving     0.369259  2025-01-02    0.789474            0.44
#
#       Alcohol_Level           Comments Alcoholic Overspeed  \
# 2059           0.04                NaN       Yes       Yes
# 564            0.96    Repeat Offender       Yes       Yes
# 2847           0.58                NaN       Yes        No
# 1701           0.04    First Violation       Yes        No
# 3380           0.58  Fine Paid On Spot       Yes        No
# ...             ...                ...       ...       ...
# 1528           0.56  Fine Paid On Spot       Yes       Yes
# 3243           0.20  Fine Paid On Spot       Yes       Yes
# 2140           0.78                NaN       Yes       Yes
# 723            0.68  Fine Paid On Spot       Yes       Yes
# 732            0.48                NaN       Yes       Yes
#
#      Overspeed_and_Alcoholic
# 2059                     Yes
# 564                      Yes
# 2847                      No
# 1701                      No
# 3380                      No
# ...                      ...
# 1528                     Yes
# 3243                     Yes
# 2140                     Yes
# 723                      Yes
# 732                      Yes
#
# [3200 rows x 10 columns]

# %% [markdown]
# # ENCODING CATAGORICAL DATA SET

# %%
train_df[catagorical_col]
from sklearn.preprocessing import OneHotEncoder

# %%
encoder=OneHotEncoder(sparse_output=False,handle_unknown='ignore')

# %%
encoder.fit(train_df[catagorical_col])
# Out:
# OneHotEncoder(handle_unknown='ignore', sparse_output=False)

# %%
encoder.categories_
# Out:
# [array(['Driving Without License', 'Drunk Driving', 'No Helmet',
#         'No Seatbelt', 'Over-speeding', 'Overloading', 'Signal Jumping',
#         'Using Mobile Phone', 'Wrong Parking'], dtype=object),
#  array(['2023-01-01', '2023-01-02', '2023-01-03', ..., '2033-12-11',
#         '2033-12-12', '2033-12-13'], dtype=object),
#  array(['Fine Paid On Spot', 'First Violation', 'Repeat Offender', nan],
#        dtype=object),
#  array(['No', 'Yes'], dtype=object),
#  array(['No', 'Yes'], dtype=object),
#  array(['No', 'Yes'], dtype=object)]

# %%
encoded_cols=list(encoder.get_feature_names_out(catagorical_col))

# %%
encoded_array=encoder.transform(train_df[catagorical_col])
train_inputs[encoded_cols]=encoder.transform(train_inputs[catagorical_col])
# Out:
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# <ipython-input-149-00981f6dec34>:2: PerformanceWarning:
#
# ...
# 3243              0.0              0.0              0.0              0.0
# 2140              0.0              0.0              0.0              0.0
# 723               0.0              0.0              0.0              0.0
# 732               0.0              0.0              0.0              0.0
#
#       Date_2033-09-30  Date_2033-10-01  Date_2033-10-03  Date_2033-10-04  \
# 2059              0.0              0.0              0.0              0.0
# 564               0.0              0.0              0.0              0.0
# 2847              0.0              0.0              0.0              0.0
# 1701              0.0              0.0              0.0              0.0
# 3380              0.0              0.0              0.0              0.0
# ...               ...              ...              ...              ...
# 1528              0.0              0.0              0.0              0.0
# 3243              0.0              0.0              0.0              0.0
# 2140              0.0              0.0              0.0              0.0
# 723               0.0              0.0              0.0              0.0
# 732               0.0              0.0              0.0              0.0
#
#       Date_2033-10-05  Date_2033-10-06  Date_2033-10-08  Date_2033-10-10  \
# 2059              0.0              0.0              0.0              0.0
# 564               0.0              0.0              0.0              0.0
# 2847              0.0              0.0              0.0              0.0
# 1701              0.0              0.0              0.0              0.0
# 3380              0.0              0.0              0.0              0.0
# ...               ...              ...              ...              ...
# 1528              0.0              0.0              0.0              0.0
# 3243              0.0              0.0              0.0              0.0
# 2140              0.0              0.0              0.0              0.0
# 723               0.0              0.0              0.0              0.0
# 732               0.0              0.0              0.0              0.0
#
#       Date_2033-10-12  Date_2033-10-13  Date_2033-10-14  Date_2033-10-15  \
# 2059              0.0              0.0              0.0              0.0
# 564               0.0              0.0              0.0              0.0
# 2847              0.0              0.0              0.0              0.0
# 1701              0.0              0.0              0.0              0.0
# 3380              0.0              0.0              0.0              0.0
# ...               ...              ...              ...              ...
# 1528              0.0              0.0              0.0              0.0
# 3243              0.0              0.0              0.0              0.0
# 2140              0.0              0.0              0.0              0.0
# 723               0.0              0.0              0.0              0.0
# 564                          0.0                       0.0
# 2847                         0.0                       0.0
# 1701                         0.0                       1.0
# 3380                         1.0                       0.0
# ...                          ...                       ...
# 1528                         1.0                       0.0
# 3243                         1.0                       0.0
# 2140                         0.0                       0.0
# 723                          1.0                       0.0
# 732                          0.0                       0.0
#
#       Comments_Repeat Offender  Comments_nan  Alcoholic_No  Alcoholic_Yes  \
# 2059                       0.0           1.0           0.0            1.0
# 564                        1.0           0.0           0.0            1.0
# 2847                       0.0           1.0           0.0            1.0
# 1701                       0.0           0.0           0.0            1.0
# 3380                       0.0           0.0           0.0            1.0
# ...                        ...           ...           ...            ...
# 1528                       0.0           0.0           0.0            1.0
# 3243                       0.0           0.0           0.0            1.0
# 2140                       0.0           1.0           0.0            1.0
# 723                        0.0           0.0           0.0            1.0
# 732                        0.0           1.0           0.0            1.0
#
#       Overspeed_No  Overspeed_Yes  Overspeed_and_Alcoholic_No  \
# 2059           0.0            1.0                         0.0
# 564            0.0            1.0                         0.0
# 2847           1.0            0.0                         1.0
# 1701           1.0            0.0                         1.0
# 3380           1.0            0.0                         1.0
# ...            ...            ...                         ...
# 1528           0.0            1.0                         0.0
# 3243           0.0            1.0                         0.0
# 2140           0.0            1.0                         0.0
# 723            0.0            1.0                         0.0
# 732            0.0            1.0                         0.0
#
#       Overspeed_and_Alcoholic_Yes
# 2059                          1.0
# 564                           1.0
# 2847                          0.0
# 1701                          0.0
# 3380                          0.0
# ...                           ...
# 1528                          1.0
# 3243                          1.0
# 2140                          1.0
# 723                           1.0
# 732                           1.0
#
# [3200 rows x 3229 columns]

# %%
train_inputs.to_parquet("train_inputs.parquet")

# %%
pd.DataFrame(train_target).to_parquet("train_target.parquet")

# %%
train_input=pd.read_parquet("./train_inputs.parquet")
train_targets=pd.read_parquet("./train_target.parquet")

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression(solver="liblinear")

# %%
model.fit(train_inputs[numeric_col_final+encoded_cols],train_target)   #Targets can be catagorical be inputs cannot be catagorical
# Out:
# LogisticRegression(solver='liblinear')

# %%
model.coef_.tolist()
train_inputs[numeric_col_final+encoded_cols]
print(train_target)
# Out:
# 2059     94
# 564      73
# 2847     60
# 1701     74
# 3380     37
#        ...
# 1528     43
# 3243     85
# 2140    111
# 723      49
# 732      64
# Name: Recorded_Speed, Length: 3200, dtype: int64

# %%
list(model.intercept_)
model.intercept_[0]
# Out:
# -1.1264922683041907

# %%
weight_df=pd.DataFrame({
        "feature":numeric_col_final+encoded_cols,
         "weight":model.coef_.tolist()[0]
})



weight_df_10=weight_df.sort_values("weight",ascending=False).head(10)
sns.barplot(data=weight_df_10,x="weight",y="feature")
# Out:
# <Axes: xlabel='weight', ylabel='feature'>

# %%
weight_df_11=weight_df.sort_values("weight",ascending=True).head(10)
sns.barplot(data=weight_df_11,x="weight",y="feature")
# Out:
# <Axes: xlabel='weight', ylabel='feature'>

# %%
sns.barplot(data=weight_df.sort_values("weight",ascending=False).head(10),x="weight",y="feature")
# Out:
# <Axes: xlabel='weight', ylabel='feature'>

# %%
prediction=model.predict(train_inputs[numeric_col_final+encoded_cols])
list(train_df[target_col])
# Out:
# [94.0,
#  73.0,
#  60.0,
#  74.0,
#  37.0,
#  90.0,
#  80.0,
#  50.0,
#  34.0,
#  115.0,
#  44.0,
#  49.0,
#  54.0,
#  43.0,
#  26.0,
#  47.0,
#  105.0,
#  61.0,
#  51.0,
#  56.0,
#  53.0,
#  29.0,
#  91.0,
#  31.0,
#  52.0,
#  25.0,
#  98.0,
#  36.0,
#  86.0,
#  61.0,
#  29.0,
#  89.0,
#  104.0,
#  102.0,
#  117.0,
#  41.0,
#  71.0,
#  47.0,
#  27.0,
#  82.0,
#  61.0,
#  22.0,
#  21.0,
#  92.0,
#  42.0,
#  104.0,
#  115.0,
#  35.0,
#  108.0,
#  106.0,
#  108.0,
#  119.0,
#  106.0,
#  114.0,
#  66.0,
#  57.0,
#  106.0,
#  34.0,
#  36.0,
#  80.0,
#  40.0,
#  24.0,
#  102.0,
#  40.0,
#  33.0,
#  116.0,
#  118.0,
#  117.0,
#  57.0,
#  66.0,
#  38.0,
#  88.0,
#  34.0,
#  115.0,
#  31.0,
#  89.0,
#  24.0,
#  81.0,
#  95.0,
#  21.0,
#  110.0,
#  92.0,
#  46.0,
#  110.0,
#  90.0,
#  98.0,
#  38.0,
#  99.0,
#  72.0,
#  42.0,
#  90.0,
#  30.0,
#  97.0,
#  54.0,
#  32.0,
#  42.0,
#  120.0,
#  94.0,
#  44.0,
#  77.0,
#  113.0,
#  90.0,
#  30.0,
#  64.0,
#  118.0,
#  55.0,
#  90.0,
#  37.0,
#  48.0,
#  33.0,
#  80.0,
#  105.0,
#  29.0,
#  95.0,
#  81.0,
#  90.0,
#  78.0,
#  118.0,
#  63.0,
#  36.0,
#  47.0,
#  109.0,
#  61.0,
#  31.0,
#  76.0,
#  111.0,
#  74.0,
#  63.0,
#  20.0,
#  79.0,
#  80.0,
#  88.0,
#  38.0,
#  55.0,
#  119.0,
#  103.0,
#  44.0,
#  52.0,
#  87.0,
#  76.0,
#  25.0,
#  58.0,
#  64.0,
#  113.0,
#  62.0,
#  114.0,
#  24.0,
#  36.0,
#  34.0,
#  111.0,
#  109.0,
#  111.0,
#  25.0,
#  87.0,
#  112.0,
#  49.0,
#  88.0,
#  22.0,
#  83.0,
#  27.0,
#  86.0,
#  85.0,
#  52.0,
#  31.0,
#  87.0,
#  81.0,
#  78.0,
#  52.0,
#  98.0,
#  92.0,
#  37.0,
#  106.0,
#  64.0,
#  116.0,
#  29.0,
#  50.0,
#  86.0,
#  80.0,
#  115.0,
#  62.0,
#  100.0,
#  110.0,
#  36.0,
#  102.0,
#  48.0,
#  84.0,
#  111.0,
#  113.0,
#  116.0,
#  42.0,
#  52.0,
#  73.0,
#  32.0,
#  40.0,
#  103.0,
#  98.0,
#  45.0,
#  116.0,
#  23.0,
#  120.0,
#  33.0,
#  46.0,
#  31.0,
#  29.0,
#  65.0,
#  28.0,
#  68.0,
#  96.0,
#  78.0,
#  55.0,
#  53.0,
#  84.0,
#  96.0,
#  106.0,
#  113.0,
#  119.0,
#  114.0,
#  82.0,
#  70.0,
#  110.0,
#  40.0,
#  115.0,
#  62.0,
#  88.0,
#  73.0,
#  53.0,
#  22.0,
#  61.0,
#  48.0,
#  76.0,
#  119.0,
#  84.0,
#  49.0,
#  25.0,
#  64.0,
#  43.0,
#  21.0,
#  36.0,
#  23.0,
#  64.0,
#  21.0,
#  106.0,
#  82.0,
#  50.0,
#  46.0,
#  20.0,
#  35.0,
#  63.0,
#  95.0,
#  103.0,
#  59.0,
#  53.0,
#  38.0,
#  36.0,
#  50.0,
#  39.0,
#  120.0,
#  47.0,
#  23.0,
#  64.0,
#  84.0,
#  99.0,
#  59.0,
#  91.0,
#  117.0,
#  100.0,
#  21.0,
#  67.0,
#  47.0,
#  53.0,
#  81.0,
#  52.0,
#  46.0,
#  62.0,
#  80.0,
#  98.0,
#  27.0,
#  40.0,
#  84.0,
#  42.0,
#  33.0,
#  69.0,
#  84.0,
#  109.0,
#  77.0,
#  89.0,
#  54.0,
#  99.0,
#  108.0,
#  108.0,
#  40.0,
#  28.0,
#  49.0,
#  46.0,
#  25.0,
#  72.0,
#  32.0,
#  110.0,
#  43.0,
#  67.0,
#  93.0,
#  64.0,
#  41.0,
#  88.0,
#  29.0,
#  113.0,
#  40.0,
#  20.0,
#  63.0,
#  36.0,
#  97.0,
#  85.0,
#  55.0,
#  114.0,
#  57.0,
#  21.0,
#  43.0,
#  66.0,
#  86.0,
#  34.0,
#  86.0,
#  82.0,
#  43.0,
#  30.0,
#  85.0,
#  69.0,
#  33.0,
#  83.0,
#  63.0,
#  66.0,
#  116.0,
#  85.0,
#  37.0,
#  87.0,
#  72.0,
#  59.0,
#  24.0,
#  115.0,
#  95.0,
#  118.0,
#  92.0,
#  86.0,
#  64.0,
#  113.0,
#  97.0,
#  102.0,
#  105.0,
#  50.0,
#  111.0,
#  60.0,
#  66.0,
#  120.0,
#  111.0,
#  91.0,
#  32.0,
#  47.0,
#  108.0,
#  81.0,
#  28.0,
#  31.0,
#  89.0,
#  72.0,
#  90.0,
#  45.0,
#  64.0,
#  61.0,
#  61.0,
#  60.0,
#  24.0,
#  38.0,
#  98.0,
#  99.0,
#  64.0,
#  92.0,
#  111.0,
#  103.0,
#  35.0,
#  91.0,
#  100.0,
#  79.0,
#  57.0,
#  35.0,
#  108.0,
#  25.0,
#  62.0,
#  26.0,
#  29.0,
#  41.0,
#  94.0,
#  71.0,
#  58.0,
#  41.0,
#  119.0,
#  84.0,
#  102.0,
#  31.0,
#  78.0,
#  37.0,
#  62.0,
#  45.0,
#  68.0,
#  84.0,
#  72.0,
#  72.0,
#  43.0,
#  87.0,
#  93.0,
#  61.0,
#  93.0,
#  98.0,
#  111.0,
#  36.0,
#  69.0,
#  55.0,
#  54.0,
#  55.0,
#  108.0,
#  85.0,
#  75.0,
#  46.0,
#  101.0,
#  25.0,
#  94.0,
#  28.0,
#  34.0,
#  39.0,
#  94.0,
#  98.0,
#  89.0,
#  78.0,
#  106.0,
#  60.0,
#  112.0,
#  60.0,
#  63.0,
#  110.0,
#  52.0,
#  35.0,
#  77.0,
#  33.0,
#  26.0,
#  96.0,
#  87.0,
#  38.0,
#  111.0,
#  41.0,
#  109.0,
#  106.0,
#  28.0,
#  120.0,
#  115.0,
#  35.0,
#  104.0,
#  87.0,
#  112.0,
#  26.0,
#  37.0,
#  26.0,
#  55.0,
#  35.0,
#  39.0,
#  82.0,
#  52.0,
#  73.0,
#  65.0,
#  109.0,
#  50.0,
#  55.0,
#  111.0,
#  112.0,
#  106.0,
#  43.0,
#  29.0,
#  118.0,
#  87.0,
#  77.0,
#  72.0,
#  27.0,
#  38.0,
#  58.0,
#  32.0,
#  68.0,
#  50.0,
#  37.0,
#  56.0,
#  50.0,
#  26.0,
#  111.0,
#  31.0,
#  116.0,
#  67.0,
#  74.0,
#  32.0,
#  62.0,
#  68.0,
#  60.0,
#  29.0,
#  111.0,
#  116.0,
#  100.0,
#  82.0,
#  24.0,
#  82.0,
#  73.0,
#  41.0,
#  40.0,
#  95.0,
#  63.0,
#  33.0,
#  74.0,
#  57.0,
#  118.0,
#  54.0,
#  65.0,
#  34.0,
#  28.0,
#  36.0,
#  29.0,
#  82.0,
#  39.0,
#  40.0,
#  118.0,
#  85.0,
#  51.0,
#  25.0,
#  110.0,
#  82.0,
#  53.0,
#  120.0,
#  82.0,
#  52.0,
#  102.0,
#  39.0,
#  64.0,
#  119.0,
#  115.0,
#  65.0,
#  27.0,
#  34.0,
#  65.0,
#  106.0,
#  88.0,
#  58.0,
#  29.0,
#  102.0,
#  90.0,
#  51.0,
#  36.0,
#  95.0,
#  91.0,
#  86.0,
#  52.0,
#  55.0,
#  41.0,
#  34.0,
#  55.0,
#  29.0,
#  26.0,
#  111.0,
#  53.0,
#  109.0,
#  52.0,
#  77.0,
#  29.0,
#  25.0,
#  71.0,
#  94.0,
#  57.0,
#  ...]

# %%
print(list(prediction))
len(prediction)
columns=["Index","Predicted_Speed"]
prediction_dataframe=pd.DataFrame(prediction,columns=["Predicted_speed"])
prediction_dataframehead=prediction_dataframe.head(10)
train_target_dataframe=pd.DataFrame(train_target)
# Out:
# [94, 73, 60, 74, 29, 90, 46, 63, 34, 115, 71, 36, 54, 43, 26, 47, 105, 73, 51, 56, 55, 29, 77, 31, 52, 25, 98, 36, 100, 61, 29, 89, 102, 102, 117, 41, 71, 47, 27, 82, 58, 22, 21, 106, 42, 104, 115, 35, 108, 113, 116, 119, 106, 114, 72, 36, 106, 34, 36, 80, 40, 24, 102, 40, 36, 116, 116, 117, 57, 66, 29, 90, 34, 115, 48, 95, 20, 81, 95, 21, 110, 90, 52, 120, 91, 98, 38, 116, 71, 42, 90, 30, 115, 31, 32, 42, 120, 84, 44, 77, 113, 72, 30, 64, 118, 26, 90, 37, 48, 29, 80, 105
45, 82, 84, 72, 72, 43, 87, 99, 62, 93, 98, 111, 36, 90, 55, 73, 55, 110, 85, 75, 95, 98, 48, 116, 49, 30, 38, 115, 97, 98, 25, 82, 30, 52, 49, 46, 84, 31, 63, 48, 23, 20, 63, 21, 97, 38, 116, 39, 89, 119, 22, 38, 116, 23, 113, 59, 112, 116, 66, 96, 106, 20, 43, 42, 72, 83, 37, 22, 85, 82, 32, 94, 87, 81, 55, 60, 74, 84, 101, 119, 31, 82, 94, 47, 38, 75, 38, 95, 59, 78, 45, 99, 89, 102, 85, 72, 86, 117, 30, 97, 116, 40, 46, 94, 84, 109, 68, 82, 21, 94, 83, 20, 69, 73, 60, 107, 95, 46, 110, 85, 81, 98, 48, 94, 44, 28, 55, 21, 118, 50, 76, 29, 53, 115, 108, 64, 58, 73, 20, 38, 26, 58, 28, 94, 97, 20, 116, 36, 64, 51, 59, 120, 62, 94, 88, 113, 70, 24, 98, 35, 38, 29, 118, 43, 32, 58, 47, 34, 62, 97, 53, 117, 102, 87, 105, 93, 113, 110, 45, 52, 83, 109, 23, 36, 112, 74, 71, 36, 112, 42, 36, 64, 21, 117, 93, 30, 64, 57, 34, 59, 117, 98, 99, 102, 52, 34, 38, 29, 83, 110, 42, 33, 58, 21, 30, 106, 40, 70, 33, 118, 74, 42, 113, 84, 112, 50, 63, 120, 55, 106, 98, 62, 67, 94, 61, 117, 36, 101, 25, 94, 28, 34, 39, 94, 98, 102, 77, 106, 60, 112, 60, 42, 110, 29, 53, 77, 33, 26, 116, 87, 38, 111, 41, 113, 106, 28, 119, 116, 35, 104, 102, 112, 26, 37, 26, 42, 29, 36, 82, 52, 73, 29, 109, 36, 55, 111, 112, 106, 55, 29, 118, 87, 57, 84, 20, 36, 58, 29, 68, 50, 37, 56, 60, 26, 111, 25, 116, 84, 90, 21, 62, 77, 60, 29, 94, 116, 112, 82, 30, 82, 71, 29, 40, 95, 63, 33, 74, 30, 118, 60, 25, 34, 28, ...

# %%
import pandas as pd
import plotly.express as px

combined_dataframe=merged_df = combined_dataframe = pd.merge(prediction_dataframe, 
                              train_target_dataframe, 
                              left_index=True, right_index=True)
final_df=combined_dataframe.head(20)
final_df
# Out:
#     Predicted_speed  Recorded_Speed
# 0                94              95
# 1                73              48
# 2                60              26
# 3                74             115
# 4                29             115
# 5                90              87
# 7                63             119
# 8                34              36
# 9               115             114
# 10               71             107
# 11               36              62
# 12               54              32
# 14               26              27
# 15               47              90
# 18               51              73
# 20               55              52
# 21               29              61
# 22               77              26
# 23               31              38
# 25               25              81

# %%
plt.figure(figsize=(10,6))


fig=sns.barplot(final_df,y="Predicted_speed",x=final_df.index,color="red")
fig=sns.barplot(final_df,y="Recorded_Speed",x=final_df.index,color="black")
plt.title("Comparison of Predicted Speed and Recorded Speed")
plt.xlabel("Index")
plt.ylabel("Speed")
# Out:
# Text(0, 0.5, 'Speed')

# %%
from sklearn.metrics import accuracy_score
accuracy_score(train_target,prediction)
# Out:
# 0.7025
